# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# we wan to see all rown in dataframe by using this

#pd.set_option("display.max_rows" , None)

# %%
# we read the file by this
Data = pd.read_csv("/home/abdurrehman/Data Analysis using Python/Data analysis project/Walmart.csv")

# %%
Data
# Out:
#             Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0     CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4     CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# ...              ...         ...         ...              ...            ...
# 3198  CA-2013-125794  30-09-2013  04-10-2013     Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014      Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014     Chris Cortes  United States
#
# ...

# %%
# we get access the first five rows
Data.head()
# Out:
#          Order ID  Order Date   Ship Date    Customer Name        Country  \
# 0  CA-2013-138688  13-06-2013  17-06-2013  Darrin Van Huff  United States
# 1  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 2  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 3  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
# 4  CA-2011-115812  09-06-2011  14-06-2011  Brosina Hoffman  United States
#
#           City       State     Category  \
# 0  Los Angeles  California       Labels
# 1  Los Angeles  California  Furnishings
# 2  Los Angeles  California          Art
# 3  Los Angeles  California       Phones
# 4  Los Angeles  California      Binders
#
#                                         Product Name   Sales  Quantity  Profit
# 0  Self-Adhesive Address Labels for Typewriters b...   14.62       2.0    6.87
# 1  Eldon Expressions Wood and Plastic Desk Access...   48.86       7.0   14.17
# ...

# %%
#By this we can access the last five rows

Data.tail()
# Out:
#             Order ID  Order Date   Ship Date Customer Name        Country  \
# 3198  CA-2013-125794  30-09-2013  04-10-2013  Maris LaWare  United States
# 3199  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3200  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3201  CA-2014-121258  27-02-2014  04-03-2014   Dave Brooks  United States
# 3202  CA-2014-119914  05-05-2014  10-05-2014  Chris Cortes  United States
#
#              City       State     Category  \
# 3198  Los Angeles  California  Accessories
# 3199   Costa Mesa  California  Furnishings
# 3200   Costa Mesa  California       Phones
# 3201   Costa Mesa  California        Paper
# 3202  Westminster  California   Appliances
#
#                                            Product Name   Sales  Quantity  \
# 3198  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...   36.24       1.0
# 3199  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.96       2.0
# ...

# %%
Data.shape
# Out:
# (3203, 12)

# %%
Data.size
# Out:
# 38436

# %%
Data.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer Name', 'Country',
#        'City', 'State', 'Category', 'Product Name', 'Sales', 'Quantity',
#        'Profit'],
#       dtype='object')

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   object
#  2   Ship Date      3203 non-null   object
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   float64
#  11  Profit         3203 non-null   float64
# dtypes: float64(3), object(9)
# memory usage: 300.4+ KB

# %%
Data.describe()
# Out:
#               Sales     Quantity       Profit
# count   3203.000000  3203.000000  3203.000000
# mean     226.493266     3.828910    33.849138
# std      524.876911     2.260947   174.109155
# min        0.990000     1.000000 -3399.980000
# 25%       19.440000     2.000000     3.850000
# 50%       60.840000     3.000000    11.170000
# 75%      215.810000     5.000000    33.000000
# max    13999.960000    14.000000  6719.980000

# %%
# check that how many missing value in our datframe

Data.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Customer Name    0
# Country          0
# City             0
# State            0
# Category         0
# Product Name     0
# Sales            0
# Quantity         0
# Profit           0
# dtype: int64

# %%
# now We check the duplicate rows in our dataframe if the values are unique its return False other then return true

Data.duplicated().value_counts()
# Out:
# False    3203
# dtype: int64

# %%
# now we calculate the each category total sales in from high to low

sales_by_category = Data.groupby('Category')['Sales'].sum().sort_values(ascending=False)

# %%
sales_by_category
# Out:
# Category
# Chairs         101781.36
# Phones          98684.39
# Tables          84754.60
# Storage         70532.84
# Accessories     61114.10
# Binders         55961.11
# Copiers         49749.23
# Machines        42444.14
# Bookcases       36004.18
# Appliances      30236.32
# Furnishings     30072.73
# Paper           26663.73
# Supplies        18127.12
# Art              9212.06
# Labels           5078.72
# Envelopes        4118.10
# Fasteners         923.20
# Name: Sales, dtype: float64

# %%
#now we show the above data in vertical bar charts

sales_by_category.plot(kind='bar', color='green')
plt.show()

# %%
# now we want to check the average sale of month

Data['Order Date'] = pd.to_daStetime(Data['Order Date'])
Data['Month'] = Data['Order Date'].dt.month
average_sales_per_month = Data.groupby('Month')['Sales'].mean()
average_sales_per_month
# Out:
# Month
# 1     266.847467
# 2     222.428571
# 3     276.234050
# 4     222.331633
# 5     229.070139
# 6     211.696605
# 7     261.987261
# 8     235.161869
# 9     186.921716
# 10    209.842862
# 11    204.813416
# 12    231.942423
# Name: Sales, dtype: float64

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3203 entries, 0 to 3202
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       3203 non-null   object
#  1   Order Date     3203 non-null   datetime64[ns]
#  2   Ship Date      3203 non-null   object
#  3   Customer Name  3203 non-null   object
#  4   Country        3203 non-null   object
#  5   City           3203 non-null   object
#  6   State          3203 non-null   object
#  7   Category       3203 non-null   object
#  8   Product Name   3203 non-null   object
#  9   Sales          3203 non-null   float64
#  10  Quantity       3203 non-null   float64
#  11  Profit         3203 non-null   float64
#  12  Month          3203 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(8)
# memory usage: 325.4+ KB

# %%
# now we show the line chart of average monthly sales.

average_sales_per_month.plot(kind='line', color='red', ls='--')
plt.show()

# %%
# now we want to get sales by states

sales_by_state = Data.groupby('State')['Sales'].sum().sort_values(ascending=False)
sales_by_state.plot(kind = "bar" , color = "red")
plt.show()

# %%
# creating a horizontal bar chart to show the total sales of products

sales_by_product = Data.groupby('Product Name')['Sales'].sum().sort_values(ascending=True)
sales_by_product.head(7).plot(kind='barh', color='yellow')
plt.show()

# %%
#creates a scatter plot that shows the total sales for the top 20 customers with the highest sales in the Data dataframe.

sales_by_customer = Data.groupby('Customer Name')['Sales'].sum()
plt.scatter(sales_by_customer.head(20).index, sales_by_customer.head(20).values, c ='red')
plt.xlabel('Customer')
plt.xticks(rotation=90)
plt.ylabel('Sales')
plt.show()

# %%
# Now we find the monthly sales growth percentage over time.

monthly_sales = Data.groupby(pd.Grouper(key='Order Date', freq='M'))['Sales'].sum()
monthly_sales_growth = monthly_sales.pct_change()

monthly_sales_growth
# Out:
# Order Date
# 2011-01-31         NaN
# 2011-02-28   -0.675610
# 2011-03-31    3.723285
# 2011-04-30   -0.034540
# 2011-05-31   -0.283761
# 2011-06-30    0.244630
# 2011-07-31    1.545695
# 2011-08-31   -0.478225
# 2011-09-30    0.881000
# 2011-10-31   -0.419558
# 2011-11-30    0.345744
# 2011-12-31    0.543136
# 2012-01-31   -0.372094
# 2012-02-29   -0.575900
# 2012-03-31    1.529868
# 2012-04-30   -0.507228
# 2012-05-31    0.564529
# 2012-06-30   -0.384873
# 2012-07-31   -0.030426
# 2012-08-31    0.478518
# 2012-09-30   -0.062484
# 2012-10-31    0.219978
# 2012-11-30   -0.073614
# 2012-12-31    0.387495
# 2013-01-31   -0.631807
# 2013-02-28   -0.106656
# 2013-03-31    1.571976
# 2013-04-30   -0.008253
# 2013-05-31    0.184157
# 2013-06-30   -0.064709
# 2013-07-31   -0.056771
# 2013-08-31    0.126620
# 2013-09-30    0.084162
# 2013-10-31   -0.342888
# 2013-11-30    1.199331
# 2013-12-31    0.070925
# 2014-01-31   -0.570555
# 2014-02-28    0.550901
# 2014-03-31    0.970979
# ...

# %%
# Now we creating a line plot to visualize the monthly sales growth percentage over time.

monthly_sales_growth.plot(kind='line', ls='-', color='orange')
plt.xlabel('Month')
plt.ylabel('Sales Growth')
plt.show()

# %%
sales_by_month_category = Data.groupby(['Month', 'Category'])['Sales'].sum().unstack()
sales_by_month_category
# Out:
# Category  Accessories  Appliances      Art   Binders  Bookcases    Chairs  \
# Month
# 1              935.53       94.61   310.56   1196.95    1375.70  11638.58
# 2             2444.41     1725.92    50.09    847.17    1137.12   1961.15
# 3             3114.26     1627.78   582.39   3010.09    2558.53   6661.34
# 4             8509.35     4423.61   607.93   4048.06    1150.65   8685.40
# 5             3142.83     2076.88  1604.70   1754.72    4257.48   6647.33
# 6             3288.54     2046.55  1153.68   5901.09    1846.75   3346.70
# 7             5996.35     1248.04   650.73   1332.93    3706.10  10513.71
# 8             7555.99     5700.63   582.32   5656.10    2754.57   8104.78
# 9             3066.24     3325.03   987.96   7723.65    6499.30   8594.54
# 10            5160.87     4138.19   864.70  11555.99    2625.08   9232.15
# 11            5879.18     2080.75  1103.53   6907.00    6333.12  12512.94
# 12           12020.55     1748.33   713.47   6027.36    1759.78  13882.74
# ...

# %%
#this code is a useful way to visualize sales trends across different categories over time. 
#The resulting heatmap allows us to easily identify which categories had the highest sales in each month,

plt.pcolor(sales_by_month_category, cmap='Blues')
plt.xlabel('Category')
plt.ylabel('Month')
plt.xticks(rotation=45)
plt.colorbar()
plt.show()
